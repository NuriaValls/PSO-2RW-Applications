# %%
failures = [18, 14, 4, 2, 1, 1, 0, 1, 2, 11]
w = [0, 0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.2, 1.4]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,5))
plt.plot(w, failures, "k", marker = "s")
plt.xlabel("inertia weight")
plt.ylabel("number of failures")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d73aa9b2053b> in <module>
#       4 plt.plot(w, failures, "k", marker = "s")
#       5 plt.xlabel("inertia weight")
# ----> 6 plt.ylabel("number of failures")
#
# TypeError: 'str' object is not callable
