# %%
import matplotlib.pyplot as plt

# %%
file = open('Base_PSO/converge_plot.txt')

# %%
for line in file:
    aux = line.rstrip('\n').split('/')

# %%
aux
# Out:
# ['0 1.632033 ',
#  'n1 0.455235 ',
#  'n2 0.339175 ',
#  'n3 0.339175 ',
#  'n4 0.339175 ',
#  'n5 0.339175 ',
#  'n6 0.339175 ',
#  'n7 0.339175 ',
#  'n8 0.339175 ',
#  'n9 0.339175 ',
#  'n10 0.137351 ',
#  'n11 0.137351 ',
#  'n12 0.137351 ',
#  'n13 0.137351 ',
#  'n14 0.137351 ',
#  'n15 0.137351 ',
#  'n16 0.137351 ',
#  'n17 0.137351 ',
#  'n18 0.137351 ',
#  'n19 0.098879 ',
#  'n20 0.098879 ',
#  'n21 0.098879 ',
#  'n22 0.098879 ',
#  'n23 0.098879 ',
#  'n24 0.098879 ',
#  'n25 0.098879 ',
#  'n26 0.098879 ',
#  'n27 0.098879 ',
#  'n28 0.098879 ',
#  'n29 0.076549 ',
#  'n30 0.076549 ',
#  'n31 0.076549 ',
#  'n32 0.076549 ',
#  'n33 0.076549 ',
#  'n34 0.076549 ',
#  'n35 0.076549 ',
#  'n36 0.076549 ',
#  'n37 0.076549 ',
#  'n38 0.076549 ',
#  'n39 0.076549 ',
#  'n40 0.076549 ',
#  'n41 0.076549 ',
#  'n42 0.076549 ',
#  'n43 0.076549 ',
#  'n44 0.076549 ',
#  'n45 0.076549 ',
#  'n46 0.076549 ',
#  'n47 0.076549 ',
#  'n48 0.076549 ',
#  'n49 0.076549 ',
# ...
